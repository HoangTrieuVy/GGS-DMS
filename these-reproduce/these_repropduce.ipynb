# %%
import sys
sys.path.insert(0, '../python_dms/lib/')
from tools_dms import *
from dms import *
from PIL import Image
import scipy.io as sio
import matplotlib.pyplot as plt
import scipy.io
import time 
# %load_ext autoreload
# %autoreload 2

# %%
np.random.seed(0)

x = np.array(Image.open('../testset/10081.jpg'))/255.
r,l,_ = np.shape(x)
delta= 0.03
# print(np.random.normal(0,1,x.shape).shape)
z = x+ delta*np.random.normal(0,1,x.shape)

# %%
## Without GGS
slpam_solver = DMS(
        norm_type="l1",
        edges="similar",
        beta=8,
        lamb=2e-3,
        eps=0.2,
        stop_criterion=1e-4,
        MaximumIteration=500,
        method="SLPAM",
        noised_image_input=z,
        optD="OptD",
        dk_SLPAM_factor=1e-4,
        eps_AT_min=0.02,
        A=np.ones((r,l)))
palm_solver = DMS(
        norm_type="l1",
        edges="similar",
        beta=8,
        lamb=7e-2,
        eps=0.2,
        stop_criterion=1e-4,
        MaximumIteration=500,
        method="PALM",
        noised_image_input=z,
        optD="OptD",
        eps_AT_min=0.02,
        A=np.ones((r,l)))
# Out:
# Color image
# Image is already in float [0,1]
#
# Color image
# Image is already in float [0,1]

# %%
## Without GGS
slpam_at_solver = DMS(
        norm_type="AT",
        edges="similar",
        beta=8,
        lamb=2e-3,
        eps=0.2,
        stop_criterion=1e-4,
        MaximumIteration=500,
        method="SLPAM-eps-descent",
        noised_image_input=z,
        optD="OptD",
        dk_SLPAM_factor=1e-4,
        eps_AT_min=0.02,
        A=np.ones((r,l)))
palm_at_solver = DMS(
        norm_type="AT",
        edges="similar",
        beta=8,
        lamb=7e-2,
        eps=0.2,
        stop_criterion=1e-4,
        MaximumIteration=500,
        method="PALM-eps-descent",
        noised_image_input=z,
        optD="OptD",
        eps_AT_min=0.02,
        A=np.ones((r,l)))
# Out:
# Color image
# Image is already in float [0,1]
#
# Color image
# Image is already in float [0,1]

# %%
time1 = time.time()
out_slpam = slpam_solver.process()
time_slpam = time.time()-time1
# Out:
#   3%|█▉                                                            | 16/500 [00:02<01:02,  7.74it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 time1 = time.time()
# ----> 2 out_slpam = slpam_solver.process()
#       3 time_slpam = time.time()-time1
#
# File ~/Documents/GitHub/GGS-DMS/these-reproduce/../python_dms/lib/dms.py:636, in DMS.process(self)
#     633 def process(self):
#     635     if self.method == "SLPAM":
# --> 636         return self.loop_SL_PAM()
#     637     elif self.method == "PALM":
#     638         return self.loop_PALM()
#
# File ~/Documents/GitHub/GGS-DMS/these-reproduce/../python_dms/lib/dms.py:591, in DMS.loop_SL_PAM(self)
#     589 un_pred= self.un_SLPAM
#     590 en_pred= self.en_SLPAM
# --> 591 self.un_SLPAM = self.L_prox(self.un_SLPAM- (self.beta / ck) * self.S_du(self.un_SLPAM, self.en_SLPAM), 1 / ck,self.noised_image_input)
#     592 # next_un_SLPAM = self.L_prox(self.un_SLPAM- (self.beta / ck) * self.S_du(self.un_SLPAM, self.en_SLPAM), 1 / ck,self.noised_image_input)
#     593 if self.norm_type == "l1" or self.norm_type == "l1q":
#
# File ~/Documents/GitHub/GGS-DMS/these-reproduce/../python_dms/lib/dms.py:160, in DMS.L_prox(self, x, tau, z)
#     159 def L_prox(self, x, tau, z):
# --> 160     return self.prox.L2_restoration(x, tau, z, self.A.astype("complex128"),self.canal)
#
# File ~/Documents/GitHub/GGS-DMS/these-reproduce/../python_dms/lib/dms.py:703, in ProximityOperators.L2_restoration(self, x, tau, z, otfA, canal)
#     701 output= np.zeros_like(x)
#     702 for i in range(3):
# --> 703     temp = (fftpack.fft2(x[:,:,i], axes=(0, 1))+ tau * np.conj(otfA) * fftpack.fft2(z[:,:,i], axes=(0, 1))) / (tau * np.conj(otfA) * otfA + 1)
#     704     temp = fftpack.ifft2(temp, axes=(0, 1))
#     705     output[:,:,i] = np.real(temp)
#
# File ~/anaconda3/lib/python3.9/site-packages/scipy/fftpack/_basic.py:394, in fft2(x, shape, axes, overwrite_x)
#     370 def fft2(x, shape=None, axes=(-2,-1), overwrite_x=False):
#     371     """
#     372     2-D discrete Fourier transform.
#     373
#    (...)
#     392     True
#     393     """
# --> 394     return fftn(x,shape,axes,overwrite_x)
#
# File ~/anaconda3/lib/python3.9/site-packages/scipy/fftpack/_basic.py:335, in fftn(x, shape, axes, overwrite_x)
#     277 """
#     278 Return multidimensional discrete Fourier transform.
#     279
#    (...)
#     332
#     333 """
#     334 shape = _good_shape(x, shape, axes)
# --> 335 return _pocketfft.fftn(x, shape, axes, None, overwrite_x)
#
# File ~/anaconda3/lib/python3.9/site-packages/scipy/fft/_pocketfft/basic.py:195, in c2cn(forward, x, s, axes, norm, overwrite_x, workers, plan)
#     192 norm = _normalization(norm, forward)
#     193 out = (tmp if overwrite_x and tmp.dtype.kind == 'c' else None)
# --> 195 return pfft.c2c(tmp, axes, forward, norm, out, workers)
#
# KeyboardInterrupt:

# %%
time2 = time.time()
out_palm = palm_solver.process()
time_palm= time.time()-time2

print("SLPAM-CT:",time_slpam)
print("PALM-CT:",time_palm)

# %%
time1 = time.time()
out_slpam_at = slpam_at_solver.process()
time_slpam_at = time.time()-time1
# Out:
# 0.2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 time1 = time.time()
# ----> 2 out_slpam_at = slpam_at_solver.process()
#       3 time_slpam_at = time.time()-time1
#
# File ~/Documents/GitHub/GGS-DMS/these-reproduce/../python_dms/lib/dms.py:639, in DMS.process(self)
#     637     return self.loop_PALM()
#     638 elif self.method == "SLPAM-eps-descent":
# --> 639     return  self.loop_SL_PAM_eps_descent()
#     640 elif self.method == "PALM-eps-descent":
#     641     return self.loop_PALM_eps_descent()
#
# File ~/Documents/GitHub/GGS-DMS/these-reproduce/../python_dms/lib/dms.py:529, in DMS.loop_SL_PAM_eps_descent(self)
#     527 block2 = csc_matrix(identity(self.rowscols * 2) * C1)
#     528 block3 = C2 * csc_matrix(self.optD1.T.dot(self.optD1))
# --> 529 mat = block1 + block2 + block3
#     530 # temp = cp.asnumpy(spsolve_cuda(mat, cp.asarray(e_ravel)))# spsolve(mat, e_ravel)
#     531 # temp= spsolve(mat, e_ravel)
#     532 temp,info = lgmres(mat, e_ravel)
#
# File ~/anaconda3/lib/python3.9/site-packages/scipy/sparse/_base.py:471, in spmatrix.__add__(self, other)
#     469 elif isspmatrix(other):
#     470     if other.shape != self.shape:
# --> 471         raise ValueError("inconsistent shapes")
#     472     return self._add_sparse(other)
#     473 elif isdense(other):
#
# ValueError: inconsistent shapes

# %%
time2 = time.time()
out_palm_at = palm_at_solver.process()
time_palm_at= time.time()-time2
# Out:
# Epsilon:  0.2
# Epsilon:  0.13333333333333333
# Epsilon:  0.08888888888888889
# Epsilon:  0.05925925925925926
# Epsilon:  0.03950617283950617
# Epsilon:  0.02633744855967078

# %%
# print("SLPAM-CT:",time_slpam_at)
print("PALM-CT:",time_palm)

# %%
plt.figure()
plt.plot(out_slpam[2],label='SLPAM')
plt.plot(out_palm[2],label='PALM')
plt.legend()
plt.figure()
plt.grid("on")
plt.loglog(out_slpam[3],label='SLPAM')
plt.loglog(out_palm[3],label='PALM')
plt.legend()
plt.figure()
plt.grid("on")
plt.loglog(out_slpam[4],label='SLPAM')
plt.loglog(out_palm[4],label='PALM')
plt.legend()

# %%
plt.figure()
plt.plot(out_slpam_at[2],label='SLPAM_at')
plt.plot(out_palm_at[2],label='PALM_at')
plt.legend()
plt.figure()
plt.grid("on")
plt.loglog(out_slpam_at[3],label='SLPAM_at')
plt.loglog(out_palm_at[3],label='PALM_at')
plt.legend()
plt.figure()
plt.grid("on")
plt.loglog(out_slpam_at[4],label='SLPAM_at')
plt.loglog(out_palm_at[4],label='PALM_at')
plt.legend()

# %%
plt.figure(figsize=(20,10))
plt.subplot(121)
plt.imshow(x)
plt.subplot(122)
plt.imshow(z)
plt.axis('off')

# %%
plt.figure(figsize=(20,10))
plt.subplot(121)
plt.axis('off')
plt.imshow(out_slpam[1])
plt.subplot(122)
plt.imshow(out_palm[1])
plt.axis('off')

# %%
plt.figure(figsize=(20,10))
# plt.subplot(121)
# plt.axis('off')
# plt.imshow(out_slpam[1])
plt.subplot(122)
plt.imshow(out_palm_at[1])
plt.axis('off')
# Out:
# [autoreload of dms failed: Traceback (most recent call last):
#   File "/home/hoangtrieuvy/anaconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/hoangtrieuvy/anaconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/hoangtrieuvy/anaconda3/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 983, in get_code
#   File "<frozen importlib._bootstrap_external>", line 913, in source_to_code
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/home/hoangtrieuvy/Documents/GitHub/GGS-DMS/these-reproduce/../python_dms/lib/dms.py", line 513
#     self.en_SLPAM = (self.en_SLPAM+ 2 * self.beta / (self.dk_SLPAM_factor) * np.sum(self.optD(self.un_SLPAM)** 2),axis=3)
#                                                                                                                       ^
# SyntaxError: invalid syntax
# ]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (-0.5, 480.5, 320.5, -0.5)

# %%
plt.figure(figsize=(20,10))
plt.imshow(out_palm_at[0][:,:,0]+out_palm_at[0][:,:,0],cmap='gray_r')
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(20,10))
# ax1=plt.subplot(121)
# plt.imshow(np.ones_like(x))
# draw_contour(out_slpam[0], '', fig=ax1, color="r", threshold=0.)
# plt.axis('off')
ax2=plt.subplot(122)
plt.imshow(np.ones_like(x))
draw_contour(out_palm[0], '', fig=ax2, color="r", threshold=0.)
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(20,10))
# ax1=plt.subplot(121)
# plt.imshow(np.ones_like(x))
# draw_contour(out_slpam[0], '', fig=ax1, color="r", threshold=0.)
# plt.axis('off')
ax2=plt.subplot(122)
plt.imshow(np.ones_like(x))
draw_contour(out_palm_at[0], '', fig=ax2, color="k", threshold=0.)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 8>()
#       6 ax2=plt.subplot(122)
#       7 plt.imshow(np.ones_like(x))
# ----> 8 draw_contour(out_palm_at[0], '', fig=ax2, color="k", threshold=0.)
#       9 plt.axis('off')
#      10 plt.show()
#
# File ~/Documents/GitHub/GGS-DMS/these-reproduce/../python_dms/lib/tools_dms.py:123, in draw_contour(e, name, fig, color, threshold)
#     119     plt.plot(
#     120         [xv[i] - 0.5, xv[i] + 0.5], [(yv[i] + 0.5), (yv[i] + 0.5)], color + "-"
#     121     )
#     122 for i in range(0, len(xh)):
# --> 123     plt.plot(
#     124         [xh[i] + 0.5, xh[i] + 0.5], [(yh[i] - 0.5), (yh[i] + 0.5)], color + "-"
#     125     )
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2988, in plot(scalex, scaley, data, *args, **kwargs)
#    2986 @_copy_docstring_and_deprecators(Axes.plot)
#    2987 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2988     return gca().plot(
#    2989         *args, scalex=scalex, scaley=scaley,
#    2990         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1607, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1605 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606 for line in lines:
# -> 1607     self.add_line(line)
#    1608 self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1609 return lines
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:2101, in _AxesBase.add_line(self, line)
#    2097 def add_line(self, line):
#    2098     """
#    2099     Add a `.Line2D` to the axes' lines; return the line.
#    2100     """
# -> 2101     self._set_artist_props(line)
#    2102     if line.get_clip_path() is None:
#    2103         line.set_clip_path(self.patch)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:1095, in _AxesBase._set_artist_props(self, a)
#    1092 if not a.is_transform_set():
#    1093     a.set_transform(self.transData)
# -> 1095 a.axes = self
#    1096 if a.mouseover:
#    1097     self._mouseover_set.add(a)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/lines.py:639, in Line2D.axes(self, ax)
#     636 if ax is not None:
#     637     for axis in ax._get_axis_map().values():
#     638         axis.callbacks._pickled_cids.add(
# --> 639             axis.callbacks.connect('units', self.recache_always))
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:335, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     330     warn_deprecated(
#     331         since, message=f"The {old!r} parameter of {func.__name__}() "
#     332         f"has been renamed {new!r} since Matplotlib {since}; support "
#     333         f"for the old name will be dropped %(removal)s.")
#     334     kwargs[new] = kwargs.pop(old)
# --> 335 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:205, in CallbackRegistry.connect(self, signal, func)
#     203 self._func_cid_map.setdefault(signal, {})
#     204 proxy = _weak_or_strong_ref(func, self._remove_proxy)
# --> 205 if proxy in self._func_cid_map[signal]:
#     206     return self._func_cid_map[signal][proxy]
#     207 cid = next(self._cid_gen)
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7f5b40799670> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:121, in flush_figures()
#     118 if InlineBackend.instance().close_figures:
#     119     # ignore the tracking, just draw and close all figures
#     120     try:
# --> 121         return show(True)
#     122     except Exception as e:
#     123         # safely show traceback if in IPython, else raise
#     124         ip = get_ipython()
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:41, in show(close, block)
#      39 try:
#      40     for figure_manager in Gcf.get_all_fig_managers():
# ---> 41         display(
#      42             figure_manager.canvas.figure,
#      43             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44         )
#      45 finally:
#      46     show._to_draw = []
#
# File ~/anaconda3/lib/python3.9/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/anaconda3/lib/python3.9/site-packages/IPython/core/formatters.py:178, in DisplayFormatter.format(self, obj, include, exclude)
#     176 md = None
#     177 try:
# --> 178     data = formatter(obj)
#     179 except:
#     180     # FIXME: log the exception
#     181     raise
#
# File ~/anaconda3/lib/python3.9/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/anaconda3/lib/python3.9/site-packages/IPython/core/formatters.py:222, in catch_format_error(method, self, *args, **kwargs)
#     220 """show traceback on failed format call"""
#     221 try:
# --> 222     r = method(self, *args, **kwargs)
#     223 except NotImplementedError:
#     224     # don't warn on NotImplementedErrors
#     225     return self._check_return(None, args[0])
#
# File ~/anaconda3/lib/python3.9/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py:2230, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2226     ctx = (renderer._draw_disabled()
#    2227            if hasattr(renderer, '_draw_disabled')
#    2228            else suppress())
#    2229     with ctx:
# -> 2230         self.figure.draw(renderer)
#    2232 if bbox_inches:
#    2233     if bbox_inches == "tight":
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer, *args, **kwargs)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py:2737, in Figure.draw(self, renderer)
#    2734         # ValueError can occur when resizing a window.
#    2736 self.patch.draw(renderer)
# -> 2737 mimage._draw_list_compositing_images(
#    2738     renderer, self, artists, self.suppressComposite)
#    2740 for sfig in self.subfigs:
#    2741     sfig.draw(renderer)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer, *args, **kwargs)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:431, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     421     deprecation_addendum = (
#     422         f"If any parameter follows {name!r}, they should be passed as "
#     423         f"keyword, not positionally.")
#     424     warn_deprecated(
#     425         since,
#     426         name=repr(name),
#    (...)
#     429                  else deprecation_addendum,
#     430         **kwargs)
# --> 431 return func(*inner_args, **inner_kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:2925, in _AxesBase.draw(self, renderer, inframe)
#    2922         a.draw(renderer)
#    2923     renderer.stop_rasterizing()
# -> 2925 mimage._draw_list_compositing_images(renderer, self, artists)
#    2927 renderer.close_group('axes')
#    2928 self.stale = False
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer, *args, **kwargs)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/lines.py:773, in Line2D.draw(self, renderer)
#     770 tpath, affine = (self._get_transformed_path()
#     771                  .get_transformed_path_and_affine())
#     772 if len(tpath.vertices):
# --> 773     gc = renderer.new_gc()
#     774     self._set_gc_clip(gc)
#     775     gc.set_url(self.get_url())
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py:676, in RendererBase.new_gc(self)
#     674 def new_gc(self):
#     675     """Return an instance of a `.GraphicsContextBase`."""
# --> 676     return GraphicsContextBase()
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py:755, in GraphicsContextBase.__init__(self)
#     753 self._forced_alpha = False  # if True, _alpha overrides A from RGBA
#     754 self._antialiased = 1  # use 0, 1 not True, False for extension code
# --> 755 self._capstyle = CapStyle('butt')
#     756 self._cliprect = None
#     757 self._clippath = None
#
# File ~/anaconda3/lib/python3.9/enum.py:384, in EnumMeta.__call__(cls, value, names, module, qualname, type, start)
#     359 """
#     360 Either returns an existing member, or creates a new enum class.
#     361
#    (...)
#     381 `type`, if set, will be mixed in as the first base class.
#     382 """
#     383 if names is None:  # simple value lookup
# --> 384     return cls.__new__(cls, value)
#     385 # otherwise, functional API: we're creating a new Enum type
#     386 return cls._create_(
#     387         value,
#     388         names,
#    (...)
#     392         start=start,
#     393         )
#
# File ~/anaconda3/lib/python3.9/enum.py:680, in Enum.__new__(cls, value)
#     677 # by-value search for a matching enum member
#     678 # see if it's in the reverse mapping (for hashable values)
#     679 try:
# --> 680     return cls._value2member_map_[value]
#     681 except KeyError:
#     682     # Not found, no need to do long O(n) search
#     683     pass
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(20,10))
ax1=plt.subplot(121)
plt.imshow(out_slpam[0][:,:,0],cmap='gray')
plt.axis('off')
ax2=plt.subplot(122)
plt.imshow(np.ones_like(x))
plt.imshow(out_palm[0][:,:,0],cmap='gray')
plt.axis('off')
plt.show()

# %%
plt.figure()
plt.hist(out_slpam[0][:,:,0].flatten(),bins=5)
plt.show()
plt.figure()
plt.hist(out_slpam[0][:,:,1].flatten(),bins=5)
plt.show()
plt.figure()
plt.hist(out_palm[0][:,:,0].flatten(),bins=5)
plt.show()
plt.figure()
plt.hist(out_palm[0][:,:,1].flatten(),bins=5)
plt.show()

# %%
data = scipy.io.loadmat('../testset/data_102061.mat')

# %%
z102061 = data['y_ref']
A = data['otfA']
X_ref= data['f']

# %%
## Without GGS
slpam_solver = DMS(
        norm_type="l1",
        edges="similar",
        beta=5,
        lamb=1.5e-3,
        eps=0.2,
        stop_criterion=1e-4,
        MaximumIteration=500,
        method="SLPAM",
        noised_image_input=z102061,
        optD="OptD",
        dk_SLPAM_factor=1e-4,
        eps_AT_min=0.02,
        A=A)
# palm_solver = DMS(
#         norm_type="l1",
#         edges="similar",
#         beta=8,
#         lamb=7e-2,
#         eps=0.2,
#         stop_criterion=1e-4,
#         MaximumIteration=500,
#         method="PALM",
#         noised_image_input=z,
#         optD="OptD",
#         eps_AT_min=0.02,
#         A=np.ones((r,l)))

# %%
plt.figure(figsize=(20,10))
plt.subplot(121)
plt.imshow(x_ref)
plt.axis('off')
plt.subplot(122)
plt.imshow(noised_image_input)
plt.axis('off')
plt.show()

# %%
time1 = time.time()
out_slpam = slpam_solver.process()
time_slpam = time.time()-time1

# %%
plt.figure(figsize=(20,10))
plt.subplot(121)
plt.axis('off')
plt.imshow(out_slpam[1])
# plt.subplot(122)
# plt.imshow(out_palm[1])
plt.axis('off')

# %%
X_est = out_slpam[1]

# %%
scipy.io.savemat('SLPAML1_IR_102061.mat',dict(x_ref=X_ref,res=X_est,y_ref=z102061))

# %%
def normalize(x):
    return (x-np.min(x))/(np.max(x)-np.min(x))

# %%
cont_norm = normalize(out_slpam[0][:,:,0]+out_slpam[0][:,:,1])

# %%
plt.imsave(fname='my_image.png', arr=np.clip(X_est,0,1), format='png')

# %%
plt.imsave(fname='cont_SLPAML1_102061.png', arr=cont_norm,cmap='gray_r', format='png')

# %%
zx = 128
zy = 128
scale = 2
rect = [100, 100, zx, zy]

# Assuming `res` is your input image as a NumPy array

# Crop the region of interest
roi_xest = cont_norm[rect[1]:rect[1]+rect[3], rect[0]:rect[0]+rect[2]]

# Resize the cropped region of interest
zoom_roi_cont = zoom_roi = np.kron(roi_xest, np.ones((scale, scale)))

# %%
plt.imsave(fname='zoom_cont_SLPAML1_102061.png', arr=zoom_roi_cont,cmap='gray_r', format='png')

# %%
plt.hist(zoom_roi_cont)

# %%
plt.imshow(zoom_roi_cont,cmap='gray_r')

# %%
x.shape

# %%
ax1=plt.figure(figsize=(np.shape(x)[1]//15,np.shape(x)[0]//15))
plt.imshow(np.ones_like(x_ref))
draw_contour(out_slpam[0], '', fig=ax1, color="k", threshold=0.)
plt.axis('off')
# ax2=plt.subplot(122)
# plt.imshow(np.ones_like(x))
# draw_contour(out_palm[0], '', fig=ax2, color="r", threshold=0.)
# plt.axis('off')
plt.savefig("cont_SLPAML1_102061.png", bbox_inches='tight', pad_inches=0,dpi=300,transparent=True)
plt.show()

# %%
zoom_cont= out_slpam[0][rect[1]:rect[1]+rect[3], rect[0]:rect[0]+rect[2]]

# %%
ax2=plt.figure(figsize=(20,20))
plt.imshow(np.ones((128,128)),cmap='gray_r')
draw_contour(zoom_cont, '', fig=ax2, color="k", threshold=0.)
plt.axis('off')
# ax2=plt.subplot(122)
# plt.imshow(np.ones_like(x))
# draw_contour(out_palm[0], '', fig=ax2, color="r", threshold=0.)
# plt.axis('off')
plt.savefig("zoom_cont_SLPAML1_102061.png", bbox_inches='tight', pad_inches=0,dpi=300,transparent=True)
plt.show()
